# %%
import pandas as pd
import numpy as np
import redis

# %%
r = redis.Redis(host='localhost', port=6379, db=0)

# %%
df= pd.read_excel('C:/Users/49152/Downloads/Ojal/IS-Redis/monster_com-job_sample.xls')

# %%
df.head(5)
# Out:
#                     country country_code date_added has_expired  \
# 0  United States of America           US 2016-10-05          No
# 1  United States of America           US 2016-10-06          No
# 2  United States of America           US 2016-10-07          No
# 3  United States of America           US 2016-10-08          No
# 4  United States of America           US 2016-10-09          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
# 3  jobs.monster.com  Why Join Altec? If you’re considering a care...
# 4  jobs.monster.com  Position ID#  76162 # Positions  1 State  C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# ...

# %%
df.drop(df.iloc[:, 14:256], inplace = True, axis = 1)
df
# Out:
#                         country country_code date_added has_expired  \
# 0      United States of America           US 2016-10-05          No
# 1      United States of America           US 2016-10-06          No
# 2      United States of America           US 2016-10-07          No
# 3      United States of America           US 2016-10-08          No
# 4      United States of America           US 2016-10-09          No
# ...                         ...          ...        ...         ...
# 16378  United States of America           US 2018-06-02          No
# 16379  United States of America           US 2018-06-03          No
# 16380  United States of America           US 2018-06-04          No
# 16381  United States of America           US 2018-06-05          No
# 16382  United States of America           US 2018-06-06          No
#
#               job_board                                    job_description  \
# ...

# %%
conn = redis.Redis('localhost')

user1 = {"Name":"Pradeep", "Company":"SCTL", "Address":"Mumbai", "Location":"RCP"}
user2 = {"Name":"Praveen", "Company":"IBM", "Address":"Mumbai", "Location":"RCP"}

# %%
r.hmset("pythonDict1", user1)
r.hmset("pythonDict2", user2)

r.hgetall("pythonDict3")
# Out:
# C:\Users\49152\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Redis.hmset() is deprecated. Use Redis.hset() instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\49152\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Redis.hmset() is deprecated. Use Redis.hset() instead.
# {}

# %%
df['date_added']=df['date_added'].astype(str)

# %%
for i in range(1):
    s = {"country":df['country'][i], "country_code":df['country_code'][i], "date_added":df['date_added'][i], "has_expired":df['has_expired'][i],"job_board":df['job_board'][i],"job_description":df['job_description'][i],"job_title":df['job_title'][i],"location":df['location'][i],"Type":df['Type'][i],"page_url":df['page_url'][i],"salary":df['salary'][i],"uniq_id":df['uniq_id'][i]}
    r.hmset("dict",s)
# Out:
# C:\Users\49152\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Redis.hmset() is deprecated. Use Redis.hset() instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
r.hgetall("dict")
# Out:
# {b'location': b'Madison, WI 53702',
#  b'date_added': b'2016-10-05',
#  b'job_description': b"TeamSoft is seeing an IT Support Specialist to join our client in Madison, WI. The ideal candidate must have at least 6 years of experience in the field. They need to be familiar with a variety of the field's concepts, practices, and procedures as this po",
#  b'uniq_id': b'11d599f229a80023d2f40e7c52cd941e',
#  b'country': b'United States of America',
#  b'salary': b'nan',
#  b'page_url': b'http://jobview.monster.com/it-support-technician-job-madison-wi-us-167855963.aspx?mescoid=1500134001001&jobPosition=20',
#  b'job_board': b'jobs.monster.com',
#  b'job_title': b'IT Support Technician Job in Madison',
#  b'country_code': b'US',
#  b'Type': b'organization',
#  b'has_expired': b'No'}
